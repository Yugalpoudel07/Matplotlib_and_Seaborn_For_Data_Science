# %% [markdown]
# # Matplotlib for Beginners — Simple Step-by-Step Notebook
#
# This notebook teaches **Matplotlib** in Python from zero, in very small steps.
#
# Every new idea is added **one piece at a time** so you can see exactly what changed and what effect it had.
#
# **You need:** basic Python (variables, lists). Nothing else.

# %% [markdown]
# ## 1. What is Matplotlib?
#
# Matplotlib turns numbers into pictures — line charts, bar charts, histograms, scatter plots, pie charts.
#
# **Why learn it?**
# - It is the base library that most other Python chart tools are built on
# - Works in notebooks, scripts, and websites
# - Full control over how a chart looks
#
# **When to use it vs other tools:**
# | Situation | Best Tool |
# |---|---|
# | Quick chart, full control | Matplotlib |
# | Statistical chart, less code | Seaborn |
# | Chart straight from a table of data | Pandas `.plot()` |
# | Interactive chart (hover, zoom) | Plotly / Bokeh |

# %% [markdown]
# ## 2. Setup
#
# Run this first.

# %%
# Uncomment if not installed
# !pip install matplotlib numpy

import matplotlib.pyplot as plt
import numpy as np

print("Ready!")
# Out:
# Ready!

# %% [markdown]
# ## 3. Your First Chart — a Simple Line
#
# Two steps: give some numbers, then tell matplotlib to draw them.

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 30, 25]

plt.plot(x, y)   # draw a line through the points
plt.show()        # display it

# %% [markdown]
# **What happened:** `plt.plot(x, y)` connects each `(x, y)` pair with a line. `plt.show()` displays the picture.

# %%
x_experience = [1 , 3, 5, 7, 10] # Experience
y_salary = [1500, 3777, 5123, 7020, 17800] # salary

plt.plot(x, y)
plt.show()

# %% [markdown]
# ## 4. Adding a Title and Axis Labels
#
# Same chart as before — we just add 3 new lines.

# %%
plt.plot(x, y)
plt.title("Sales Over 5 Days")   # NEW: title on top
plt.xlabel("Day")                 # NEW: label under x-axis
plt.ylabel("Units Sold")          # NEW: label beside y-axis
plt.show()

# %% [markdown]
# make a another data and make a grpah like this

# %%
plt.plot(x_experience, y_salary)
plt.title("Experience over salary")   # NEW: title on top
plt.xlabel("Experience")                 # NEW: label under x-axis
plt.ylabel("Salary")          # NEW: label beside y-axis
plt.show()

# %% [markdown]
# **What changed:** the chart is the same line, but now it has a title and labels so anyone can understand it.

# %% [markdown]
# ## 5. Changing Color, Line Style, and Markers
#
# We add extra settings inside `plt.plot()`.

# %%
plt.plot(x, y,
         color='green',      # NEW: line color
         linestyle='--',     # NEW: dashed line instead of solid
         marker='o')         # NEW: circle marker on each point
plt.title("Sales Over 5 Days")
plt.xlabel("Day")
plt.ylabel("Units Sold")
plt.show()

# %% [markdown]
# # Matplotlib Line Styles and Markers
#
# In Matplotlib, we can change the **line style** and **marker style** using `linestyle` and `marker`.
#
# ## 1. Line Styles
#
# | Linestyle | Meaning |
# |---|---|
# | `'-'` | Solid line |
# | `'--'` | Dashed line |
# | `'-.'` | Dash-dot line |
# | `':'` | Dotted line |
# | `'None'` | No line |
#
# ## 2. Marker Styles
#
# | Marker | Meaning |
# |---|---|
# | `'o'` | Circle |
# | `'s'` | Square |
# | `'^'` | Triangle up |
# | `'v'` | Triangle down |
# | `'*'` | Star |
# | `'+'` | Plus |
# | `'x'` | X |
# | `'D'` | Diamond |
# | `'.'` | Point |
#
# ## 3. Example
#
# ```python
# import matplotlib.pyplot as plt
#
# x = ["Mon", "Tue", "Wed", "Thu", "Fri"]
# y = [20, 35, 30, 45, 40]
#
# plt.plot(x, y,
#          color='green',
#          linestyle='--',
#          marker='o',
#          markersize=8)
#
# plt.title("Sales Over 5 Days")
# plt.xlabel("Day")
# plt.ylabel("Units Sold")
# plt.show()

# %%
import matplotlib.pyplot as plt

x = ["Mon", "Tue", "Wed", "Thu", "Fri"]
y = [20, 35, 30, 45, 40]

plt.plot(x, y,
         color='green',
         linestyle='--',
         marker='o',
         markersize=8)

plt.title("Sales Over 5 Days")
plt.xlabel("Day")
plt.ylabel("Units Sold")
plt.show()

# %% [markdown]
# **What changed:** same line, but now it is green, dashed, and shows a dot at every data point.

# %% [markdown]
# ## 6. Two Lines on the Same Chart
#
# Just call `plt.plot()` a second time before `plt.show()`.

# %%
product_a = [10, 20, 15, 30, 25]
product_b = [5, 15, 25, 10, 20]

plt.plot(x, product_a, marker='o', label='Product A')
plt.plot(x, product_b, marker='s', label='Product B')   # NEW: second line
plt.title("Product Sales Comparison")
plt.xlabel("Day")
plt.ylabel("Units Sold")
plt.show()

# %%
product_a = [10, 20, 15, 30, 25]
product_b = [5, 15, 25, 10, 20]

plt.plot(x, product_a, marker='o', label='Product A')
plt.plot(x, product_b, marker='s', label='Product B')   # NEW: second line
plt.legend()   # NEW: shows which color is which product
plt.title("Product Sales Comparison")
plt.xlabel("Day")
plt.ylabel("Units Sold")
plt.show()

# %% [markdown]
# **What changed:** a second `plt.plot()` line was added, plus `plt.legend()` so we know which line is which.

# %% [markdown]
# ## 7. Bar Chart
#
# Same idea as a line chart, but use `plt.bar()` instead of `plt.plot()`.

# %%
categories = ['A', 'B', 'C', 'D']
values = [23, 45, 12, 36]

plt.bar(categories, values, color='skyblue')
plt.title("Category Comparison")
plt.xlabel("Category")
plt.ylabel("Value")
plt.show()

# %%
import matplotlib.pyplot as plt

categories = ['A', 'B', 'C', 'D']
values = [23, 45, 12, 36]

plt.bar(categories, values,
        color=['red', 'blue', 'green', 'orange'])

plt.title("Category Comparison")
plt.xlabel("Category")
plt.ylabel("Value")
plt.show()

# %%
import matplotlib.pyplot as plt

categories = ['A', 'B', 'C', 'D']
values = [23, 45, 12, 36]

plt.bar(categories, values,
        color='skyblue',
        edgecolor='black',
        linewidth=1.5,
        width=0.6,
        alpha=0.9)

plt.title("Category Comparison")
plt.xlabel("Category")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# plt.bar(categories, values,
#         color='skyblue',
#         edgecolor='black',
#         linewidth=1.5,
#         width=0.6,
#         alpha=0.8)

# %% [markdown]
# test with this value

# %% [markdown]
# make a data and create bar chart

# %% [markdown]
# color='red'
# color='green'
# color='orange'
# color='purple'
# color='pink'
# color='gold'
# color='lightblue'

# %% [markdown]
# ## 8. Pie Chart
#
# Use `plt.pie()` to show parts of a whole (use only 2-6 slices).

# %%
labels = ['Rent', 'Food', 'Transport', 'Savings']
expenses = [40, 25, 15, 20]

plt.pie(expenses, labels=labels, autopct='%1.1f%%')
plt.title("Monthly Budget")
plt.show()

# %%
labels = ["Travel", "Hostel", "Edu_Fee", "Exam_fee", "Food"]
expenses = [10, 20, 40, 20, 10]

plt.pie(expenses, labels=labels, autopct='%1.1f%%')
plt.title("Monthly Budget")
plt.show()

# %% [markdown]
# Actually, the important part is:
#
# % → start of formatting
# 1.1 → display 1 decimal place
# f → floating-point number
# %% → print the actual % symbol

# %% [markdown]
# ## 9. Histogram — Built Step by Step
#
# A histogram shows how data is **spread out** (how many values fall in each range).
#
# We will build it slowly. Each step below adds **one new thing** to the same chart, so you can see exactly what changed.

# %% [markdown]
# ### Step 1: Just the data
#
# First, create some sample data — 1000 random height values.

# %%
import matplotlib.pyplot as plt

marks = [35, 38, 42, 43, 44, 46, 48, 49, 50,
         51, 53, 54, 56, 58, 60, 62, 64]

bins = [30, 35, 40, 45, 50, 55, 60, 65, 70]

plt.hist(marks, bins=bins,
         edgecolor='black')

plt.title("Marks Distribution")
plt.xlabel("Marks")
plt.ylabel("Number of Students")

plt.show()

# %% [markdown]
# plt.hist(marks, bins=bins,
#          edgecolor='black')

# %% [markdown]
# plt.hist(marks, bins=bins,
#          color='skyblue',
#          edgecolor='black')

# %% [markdown]
# plt.hist(marks, bins=bins,
#          color='skyblue',
#          edgecolor='black',
#          alpha=0.7)

# %%
import matplotlib.pyplot as plt

marks = [35, 38, 42, 43, 44, 46, 48, 49, 50,
         51, 53, 54, 56, 58, 60, 62, 64]

# Define class intervals
bins = [30, 35, 40, 45, 50, 55, 60, 65, 70]

# Create histogram
plt.hist(marks,
         bins=bins,
         color='skyblue',
         edgecolor='black',
         alpha=0.7)

# Add title and labels
plt.title("Marks Distribution")
plt.xlabel("Marks")
plt.ylabel("Number of Students")

# Add grid
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.show()

# %% [markdown]
# ### Step 2: Draw the most basic histogram
#
# Call `plt.hist()` on the data. No settings yet — just the default.

# %% [markdown]
# **What changed:** the bars are now orange with a black border, making individual bars easier to tell apart.

# %% [markdown]
# **What changed:** the chart now clearly says what it is showing — heights on the x-axis, how many people had that height on the y-axis.

# %% [markdown]
# ## 10. Scatter Plot — Built Step by Step
#
# A scatter plot shows the relationship between **two** numeric variables — one dot per data pair.
#
# We will build it the same way as the histogram: one small change at a time.

# %% [markdown]
# ### Step 1: Just the data
#
# Create two lists of the same length — hours studied and the exam score for 8 students.

# %%
hours_studied = [1, 2, 3, 3, 4, 4.2, 4.4, 4, 5.3, 5.5, 5, 5, 6, 6, 7, 8]

exam_score = [50, 55, 65, 68, 70, 72, 71, 75, 70, 73, 75, 78, 80, 82, 85, 90]

print(list(zip(hours_studied, exam_score)))
# Out:
# [(1, 50), (2, 55), (3, 65), (3, 68), (4, 70), (4.2, 72), (4.4, 71), (4, 75), (5.3, 70), (5.5, 73), (5, 75), (5, 78), (6, 80), (6, 82), (7, 85), (8, 90)]

# %% [markdown]
# **What we have:** 8 pairs of numbers — student 1 studied 1 hour and scored 50, student 2 studied 2 hours and scored 55, and so on. Nothing plotted yet.

# %% [markdown]
# ### Step 2: Draw the most basic scatter plot
#
# Call `plt.scatter(x, y)`.

# %%
plt.scatter(hours_studied, exam_score)
plt.show()

# %% [markdown]
# **What changed:** each pair of numbers is now a single dot on the chart — no lines connecting them, just points.

# %% [markdown]
# ### Step 3: Add color
#
# Add `color` to change the dot color from the default blue.

# %%
plt.scatter(hours_studied, exam_score, color='purple')   # NEW: purple dots
plt.show()

# %% [markdown]
# **What changed:** same dots, just recolored purple.

# %% [markdown]
# ### Step 4: Change dot size
#
# Add `s` (size) to make the dots bigger or smaller.

# %%
plt.scatter(hours_studied, exam_score, color='purple', s=100)   # NEW: s=100 makes dots bigger
plt.show()

# %% [markdown]
# **What changed:** the dots are now larger and easier to see. Try `s=20` for smaller dots.

# %% [markdown]
# ### Step 5: Add title and axis labels
#
# Same as always — make it readable.

# %%
plt.scatter(hours_studied, exam_score, color='purple', s=100)
plt.title("Study Hours vs Exam Score")   # NEW
plt.xlabel("Hours Studied")               # NEW
plt.ylabel("Exam Score")                  # NEW
plt.show()

# %% [markdown]
# **What changed:** now anyone looking at the chart knows exactly what it's measuring.

# %% [markdown]
# ### Step 6: Color dots by a third value
#
# Instead of one flat color, pass a **list of numbers** to `c=` — matplotlib will color each dot based on its value, like a heat scale.

# %%
plt.scatter(hours_studied, exam_score,
            c=exam_score,        # NEW: color each dot by its exam score
            s=100,
            cmap='viridis')      # NEW: cmap = the color scale to use
plt.title("Study Hours vs Exam Score")
plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")
plt.colorbar(label='Exam Score')   # NEW: shows what the colors mean
plt.show()

# %%
plt.scatter(hours_studied, exam_score,
            c=exam_score,        # NEW: color each dot by its exam score
            s=100,
            cmap='plasma')      # NEW: cmap = the color scale to use
plt.title("Study Hours vs Exam Score")
plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")
plt.colorbar(label='Exam Score')   # NEW: shows what the colors mean
plt.show()

# %% [markdown]
# **What changed:** instead of every dot being the same purple, low scores are now a different color than high scores, and a colorbar explains the scale.

# %% [markdown]
# ### Step 7 (bonus): Compare two groups on one scatter plot
#
# Just like the histogram, add a second `plt.scatter()` call to compare two groups.

# %%
group_a_hours = [1, 2, 3, 4, 5]
group_a_scores = [50, 55, 60, 58, 65]

group_b_hours = [4, 5, 6, 7, 8]
group_b_scores = [70, 75, 80, 85, 90]

plt.scatter(group_a_hours, group_a_scores, color='blue', s=100, label='Class A')
plt.scatter(group_b_hours, group_b_scores, color='red', s=100, label='Class B')   # NEW second group
plt.title("Study Hours vs Exam Score: Class A vs Class B")
plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")
plt.legend()   # NEW
plt.show()

# %% [markdown]
# **What changed:** a second `plt.scatter()` call was layered on the same chart, with its own color and label, so we can compare the two classes directly.

# %% [markdown]
# ## 12. Saving a Chart to a File
#
# Call `plt.savefig()` **before** `plt.show()`.

# %%
plt.scatter(hours_studied, exam_score, color='purple', s=100)
plt.title("Study Hours vs Exam Score")
plt.savefig("scatter_chart.png", dpi=200, bbox_inches='tight')
plt.show()
print("Saved as scatter_chart.png")
# Out:
# Saved as scatter_chart.png

# %% [markdown]
# ## 13. Alternative Libraries — and When to Use Them
#
# | Library | Best For | Value |
# |---|---|---|
# | **Matplotlib** | Full control, static charts | Most flexible, works everywhere |
# | **Seaborn** | Statistical plots (heatmaps, box plots) | Prettier defaults, less code |
# | **Pandas `.plot()`** | Quick chart from a table of data | Fastest for data you already loaded |
# | **Plotly** | Interactive charts, dashboards | Hover, zoom, web-ready |
# | **Bokeh** | Big data, interactive dashboards | Handles large datasets well |
# | **Altair** | Short, declarative chart code | Very readable syntax |
#
# **Simple rule:** exploring data → Pandas. Statistics → Seaborn. Need interactivity → Plotly/Bokeh. Need full control → Matplotlib.

# %% [markdown]
# ## 14. Practice Time — 10 Simple Tasks
#
# Try each one yourself before looking at earlier examples for hints.

# %% [markdown]
# ### Task 1: Basic Line Plot
# Plot a line chart for `x = [1,2,3,4,5]` and `y = [2,4,6,8,10]`. Add the title `"Doubling Numbers"`.

# %%
# Write your code here
x = [1,2,3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y)
plt.show()

# %% [markdown]
# ### Task 2: Label the Axes
# Redraw Task 1's chart but add the x-axis label `"Number"` and y-axis label `"Double"`.

# %%
# Write your code here

# Write your code here
x = [1,2,3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y)
plt.xlabel("Number")
plt.ylabel("Double")
plt.show()

# %% [markdown]
# ### Task 3: Change Line Color and Marker
# Plot `y = [3,1,4,1,5,9,2,6]` as a red dashed line with circle markers.

# %%
# Write your code here
y = [3, 1, 4, 1, 5, 9, 2, 6]
plt.plot(y, color="red", linestyle="--", marker="o")
plt.show()

# %% [markdown]
# ### Task 4: Two Lines with a Legend
# Plot `temp_monday = [20,22,25,23,21]` and `temp_tuesday = [18,19,24,26,22]` on the same chart with a legend.

# %%
# Write your code here
temp_monday = [20,22,25,23,21]
temp_tuesday = [18,19,24,26,22]

plt.plot(temp_monday, label="Monday")
plt.plot(temp_tuesday, label="Tuesday")
plt.legend()

# %% [markdown]
# ### Task 5: Bar Chart of Fruit Sales
# Create a bar chart for `fruits = ['Apple','Banana','Mango','Grapes']` with `sales = [50,30,45,20]`. Color the bars purple.

# %%
# Write your code here
fruits = ['Apple','Banana','Mango','Grapes']
sales = [50,30,45,20]

plt.bar(fruits, sales, color='purple')

plt.xlabel('Fruits')
plt.ylabel('Sales')
plt.title('Fruit Sales')

plt.show()

# %% [markdown]
# ### Task 7: Scatter Plot, Step by Step
# Create two lists of 10 random numbers using `np.random.randint(0, 100, 10)`. First plot a basic scatter, then re-plot with a bigger size (`s=80`) and a color.

# %%
# Write your code here

x = np.random.randint(0, 100, 10)
y = np.random.randint(0, 100, 10)

plt.scatter(x, y)
plt.show()

plt.scatter(x, y, s=80, color="purple")
plt.show()

# %% [markdown]
# ### Task 8: Pie Chart of Time Spent
# Make a pie chart for `labels = ['Sleep','Work','Leisure','Other']`, `hours = [8,8,4,4]`. Show percentages.

# %%
# Write your code here
labels = ['Sleep', 'Work', 'Leisure', 'Other']
hours = [8, 8, 4, 4]

plt.pie(hours, labels=labels, autopct='%1.1f%%')

plt.title('Daily Time Distribution')
plt.show()

# %%
# Write your code here

# %% [markdown]
# ### Task 10: Save Your Own Chart
# Create any chart of your choice, then save it as `my_first_chart.png` with `dpi=200`.

# %%
# Write your code here
x = [1, 2, 3, 4, 5]
y = [10, 25, 20, 35, 45]

plt.plot(x, y, marker='o')

plt.title('My First Chart')
plt.xlabel('X')
plt.ylabel('Y')

plt.savefig('my_first_chart.png', dpi=200)
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 25, 20, 35, 45]

plt.subplot(2, 2, 1)
plt.plot(x, y)
plt.title("Line")

plt.subplot(2, 2, 2)
plt.scatter(x, y)
plt.title("Scatter")

plt.subplot(2, 2, 3)
plt.bar(x, y, color='purple')
plt.title("bar")

plt.subplot(2, 2, 4)
plt.pie(x, labels=y, autopct='%1.1f%%')
plt.title("Pie")
# Out:
# Text(0.5, 1.0, 'Pie')
